# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52239-netizen/NLP/blob/main/Lab8_NGram_Model_Ganesh_2403a52239.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **corpus**

# %%
D1="I am working as a professor"
D2="I am working in SR University"
D3="I did my phd in NITW"
D4="I did my masters in OUCE"
D5="I completed my schooling in Warangal"
D6="I specialize in Computer Science"
D7="I have published research papers in AI"
D8="I am guiding several PhD scholars"
D9="I am passionate about teaching and mentoring"
D10="I am a member of professional academic societies"

# %% [markdown]
# **uni gram count**

# %%
import collections
combined_text=f"{D1} {D2} {D3} {D4} {D5} {D6} {D7} {D8} {D9} {D10}"
words=combined_text.lower().split()

unigram_counts = collections.Counter(words)

print("Unigram Counts:")
for word, count in unigram_counts.most_common():
    print(f"{word}: {count}")
V=len(unigram_counts)
print("Vocabulary Size=",V)
# Out:
# Unigram Counts:
# i: 10
# in: 6
# am: 5
# my: 3
# working: 2
# a: 2
# did: 2
# phd: 2
# as: 1
# professor: 1
# sr: 1
# university: 1
# nitw: 1
# masters: 1
# ouce: 1
# completed: 1
# schooling: 1
# warangal: 1
# specialize: 1
# computer: 1
# science: 1
# have: 1
# published: 1
# research: 1
# papers: 1
# ai: 1
# guiding: 1
# several: 1
# scholars: 1
# passionate: 1
# about: 1
# teaching: 1
# and: 1
# mentoring: 1
# member: 1
# of: 1
# professional: 1
# academic: 1
# societies: 1
# Vocabulary Size= 39

# %% [markdown]
# **bi gram**

# %%
words = combined_text.lower().split()

bigrams = []
for i in range(len(words) - 1):
    bigrams.append((words[i], words[i+1]))

bigram_counts = collections.Counter(bigrams)

print("\nBigram Counts:")
for bigram, count in bigram_counts.most_common():
    print(f"{bigram[0]} {bigram[1]}: {count}")
# Out:
# Bigram Counts:
# i am: 5
# am working: 2
# i did: 2
# did my: 2
# working as: 1
# as a: 1
# a professor: 1
# professor i: 1
# working in: 1
# in sr: 1
# sr university: 1
# university i: 1
# my phd: 1
# phd in: 1
# in nitw: 1
# nitw i: 1
# my masters: 1
# masters in: 1
# in ouce: 1
# ouce i: 1
# i completed: 1
# completed my: 1
# my schooling: 1
# schooling in: 1
# in warangal: 1
# warangal i: 1
# i specialize: 1
# specialize in: 1
# in computer: 1
# computer science: 1
# science i: 1
# i have: 1
# have published: 1
# published research: 1
# research papers: 1
# papers in: 1
# in ai: 1
# ai i: 1
# am guiding: 1
# guiding several: 1
# several phd: 1
# phd scholars: 1
# scholars i: 1
# am passionate: 1
# passionate about: 1
# about teaching: 1
# teaching and: 1
# and mentoring: 1
# mentoring i: 1
# am a: 1
# a member: 1
# member of: 1
# of professional: 1
# professional academic: 1
# academic societies: 1

# %% [markdown]
# **tri gram**

# %%
words = combined_text.lower().split()

trigrams = []
for i in range(len(words) - 2):
    trigrams.append((words[i], words[i+1], words[i+2]))

trigram_counts = collections.Counter(trigrams)

print("\nTrigram Counts:")
for trigram, count in trigram_counts.most_common():
    print(f"{trigram[0]} {trigram[1]} {trigram[2]}: {count}")
# Out:
# Trigram Counts:
# i am working: 2
# i did my: 2
# am working as: 1
# working as a: 1
# as a professor: 1
# a professor i: 1
# professor i am: 1
# am working in: 1
# working in sr: 1
# in sr university: 1
# sr university i: 1
# university i did: 1
# did my phd: 1
# my phd in: 1
# phd in nitw: 1
# in nitw i: 1
# nitw i did: 1
# did my masters: 1
# my masters in: 1
# masters in ouce: 1
# in ouce i: 1
# ouce i completed: 1
# i completed my: 1
# completed my schooling: 1
# my schooling in: 1
# schooling in warangal: 1
# in warangal i: 1
# warangal i specialize: 1
# i specialize in: 1
# specialize in computer: 1
# in computer science: 1
# computer science i: 1
# science i have: 1
# i have published: 1
# have published research: 1
# published research papers: 1
# research papers in: 1
# papers in ai: 1
# in ai i: 1
# ai i am: 1
# i am guiding: 1
# am guiding several: 1
# guiding several phd: 1
# several phd scholars: 1
# phd scholars i: 1
# scholars i am: 1
# i am passionate: 1
# am passionate about: 1
# passionate about teaching: 1
# about teaching and: 1
# teaching and mentoring: 1
# and mentoring i: 1
# mentoring i am: 1
# i am a: 1
# am a member: 1
# a member of: 1
# member of professional: 1
# of professional academic: 1
# professional academic societies: 1

# %% [markdown]
# *Next Word Prediction Using Bi-Gram Counts and deployment of bi gram model*

# %%
def predict_next_word_bigram(word_sequence, bigram_counts, unigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."

    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = bigram_count / last_word_unigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "I completed"
next_word1 = predict_next_word_bigram(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I specialize"
next_word2 = predict_next_word_bigram(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "professor I"
next_word3 = predict_next_word_bigram(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "nonexistent word"
next_word4 = predict_next_word_bigram(sequence4, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# probability of  my is  1.0
# Given sequence: 'I completed', predicted next word: 'my'
# probability of  in is  1.0
# Given sequence: 'I specialize', predicted next word: 'in'
# probability of  am is  0.5
# probability of  did is  0.2
# probability of  completed is  0.1
# probability of  specialize is  0.1
# probability of  have is  0.1
# Given sequence: 'professor I', predicted next word: 'am'
# Given sequence: 'nonexistent word', predicted next word: 'No bigram found starting with 'word'.'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textI completed
# probability of  my is  1.0
# Given sequence: 'I completed', predicted next word: 'my'

# %% [markdown]
# *Next Word Prediction Using Tri-Gram Counts and deployment of tri gram model*

# %%
def predict_next_word_trigram(word_sequence, trigram_counts, bigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    last_two_words_tuple = tuple(words_in_sequence[-2:])

    potential_next_words = {}
    for (w1, w2, w3), count in trigram_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = trigram_count / last_two_words_bigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "I completed"
next_word1 = predict_next_word_trigram(sequence1, trigram_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_trigram(sequence2, trigram_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  my is  1.0
# Given sequence: 'I completed', predicted next word: 'my'
# probability of  phd is  0.5
# probability of  masters is  0.5
# Given sequence: 'I did my', predicted next word: 'phd'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram(ip_text, trigram_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textI am
# probability of  working is  0.4
# probability of  guiding is  0.2
# probability of  passionate is  0.2
# probability of  a is  0.2
# Given sequence: 'I am', predicted next word: 'working'

# %% [markdown]
# *Next Word Prediction Using Bi-Gram Counts with Laplace Smoothening and deployment*

# %%
def predict_next_word_bigram_Laplace(word_sequence, bigram_counts, unigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."

    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."

    predicted_word = None
    max_probability = -1
    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+1) / (last_word_unigram_count+V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "I am"
next_word1 = predict_next_word_bigram_Laplace(sequence1, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_bigram_Laplace(sequence2, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "professor I"
next_word3 = predict_next_word_bigram_Laplace(sequence3, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "nonexistent word"
next_word4 = predict_next_word_bigram_Laplace(sequence4, bigram_counts, unigram_counts)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# probability of working is  0.06818181818181818
# probability of guiding is  0.045454545454545456
# probability of passionate is  0.045454545454545456
# probability of a is  0.045454545454545456
# Given sequence: 'I am', predicted next word: 'working'
# probability of phd is  0.047619047619047616
# probability of masters is  0.047619047619047616
# probability of schooling is  0.047619047619047616
# Given sequence: 'I did my', predicted next word: 'phd'
# probability of am is  0.12244897959183673
# probability of did is  0.061224489795918366
# probability of completed is  0.04081632653061224
# probability of specialize is  0.04081632653061224
# probability of have is  0.04081632653061224
# Given sequence: 'professor I', predicted next word: 'am'
# Given sequence: 'nonexistent word', predicted next word: 'No bigram found starting with 'word'.'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_Laplace(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textI am
# probability of working is  0.06818181818181818
# probability of guiding is  0.045454545454545456
# probability of passionate is  0.045454545454545456
# probability of a is  0.045454545454545456
# Given sequence: 'I am', predicted next word: 'working'

# %% [markdown]
# *Next Word Prediction Using Tri-Gram Counts based on laplace smoothening and deployement*

# %%
def predict_next_word_trigram_Laplace(word_sequence, trigram_counts, bigram_counts):
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    last_two_words_tuple = tuple(words_in_sequence[-2:])

    potential_next_words = {}
    for (w1, w2, w3), count in trigram_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."

    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = (trigram_count+1) / (last_two_words_bigram_count+V)
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "I am working"
next_word1 = predict_next_word_trigram_Laplace(sequence1, trigram_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_trigram_Laplace(sequence2, trigram_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  as is  0.04878048780487805
# probability of  in is  0.04878048780487805
# Given sequence: 'I am working', predicted next word: 'as'
# probability of  phd is  0.04878048780487805
# probability of  masters is  0.04878048780487805
# Given sequence: 'I did my', predicted next word: 'phd'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram_Laplace(ip_text, trigram_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textI am working
# probability of  as is  0.04878048780487805
# probability of  in is  0.04878048780487805
# Given sequence: 'I am working', predicted next word: 'as'

# %% [markdown]
# *Next Word Prediction Using Bi-Gram Counts with Add - K Smoothening and deployment*

# %%
def predict_next_word_bigram_K(word_sequence, bigram_counts, unigram_counts, K): #K=0.5-0.01
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."

    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."
    predicted_word = None
    max_probability = -1
    for next_word, bigram_count in potential_next_words.items():
        probability = (bigram_count+K) / (last_word_unigram_count+K*V)
        print("probability of " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word

sequence1 = "I am"
next_word1 = predict_next_word_bigram_K(sequence1, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_bigram_K(sequence2, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")

sequence3 = "professor I"
next_word3 = predict_next_word_bigram_K(sequence3, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence3}', predicted next word: '{next_word3}'")

sequence4 = "nonexistent word"
next_word4 = predict_next_word_bigram_K(sequence4, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{sequence4}', predicted next word: '{next_word4}'")
# Out:
# probability of working is  0.10204081632653061
# probability of guiding is  0.061224489795918366
# probability of passionate is  0.061224489795918366
# probability of a is  0.061224489795918366
# Given sequence: 'I am', predicted next word: 'working'
# probability of phd is  0.06666666666666667
# probability of masters is  0.06666666666666667
# probability of schooling is  0.06666666666666667
# Given sequence: 'I did my', predicted next word: 'phd'
# probability of am is  0.1864406779661017
# probability of did is  0.0847457627118644
# probability of completed is  0.05084745762711865
# probability of specialize is  0.05084745762711865
# probability of have is  0.05084745762711865
# Given sequence: 'professor I', predicted next word: 'am'
# Given sequence: 'nonexistent word', predicted next word: 'No bigram found starting with 'word'.'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram_K(ip_text, bigram_counts, unigram_counts,0.5)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textI specialize
# probability of in is  0.07317073170731707
# Given sequence: 'I specialize', predicted next word: 'in'

# %% [markdown]
# *Next Word Prediction Using Tri-Gram Counts with Add - K Smoothening and deployment*

# %%
def predict_next_word_trigram_K(word_sequence, trigram_counts, bigram_counts,K): #K=0.5-0.01
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."
    last_two_words_tuple = tuple(words_in_sequence[-2:])
    potential_next_words = {}
    for (w1, w2, w3), count in trigram_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count
    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."
    predicted_word = None
    max_probability = -1
    for next_word, trigram_count in potential_next_words.items():
        probability = (trigram_count+K) / (last_two_words_bigram_count+K*V)
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word
sequence1 = "I am working"
next_word1 = predict_next_word_trigram_K(sequence1, trigram_counts, bigram_counts,0.5)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "I did my"
next_word2 = predict_next_word_trigram_K(sequence2, trigram_counts, bigram_counts,0.5)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  as is  0.06976744186046512
# probability of  in is  0.06976744186046512
# Given sequence: 'I am working', predicted next word: 'as'
# probability of  phd is  0.06976744186046512
# probability of  masters is  0.06976744186046512
# Given sequence: 'I did my', predicted next word: 'phd'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram_K(ip_text, trigram_counts, bigram_counts,0.5)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textI specialize in
# probability of  computer is  0.07317073170731707
# Given sequence: 'I specialize in', predicted next word: 'computer'
